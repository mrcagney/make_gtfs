# %%
import sys
from pathlib import Path

import pandas as pd
import numpy as np
import gtfs_kit as gk

sys.path.append('../')

import make_gtfs as mg


DATA_DIR = Path('../data')

# %load_ext autoreload
# %autoreload 2

# %%
path = DATA_DIR / 'auckland'
pfeed = mg.read_protofeed(path)

# %%
pfeed.frequencies
# Out:
#   route_short_name                                    route_long_name  \
# 0                A  City Link, Wynyard Quarter to Karangahape Rd v...
# 1                A  City Link, Wynyard Quarter to Karangahape Rd v...
# 2                A  City Link, Wynyard Quarter to Karangahape Rd v...
# 3                A  City Link, Wynyard Quarter to Karangahape Rd v...
# 4                B  Inner Link. Britomart, Three Lamps, Ponsonby, ...
# 5                B  Inner Link. Britomart, Three Lamps, Ponsonby, ...
# 6                B  Inner Link. Britomart, Three Lamps, Ponsonby, ...
# 7                B  Inner Link. Britomart, Three Lamps, Ponsonby, ...
#
#    route_type shape_id service_window_id  frequency  direction  speed
# 0           3     shp1    weekday_peak_1         12          1   20.0
# 1           3     shp1    weekday_peak_2         12          1   20.0
# 2           3     shp1   weekday_offpeak          4          0   20.0
# 3           3     shp1          saturday          0          0   20.0
# 4           2     shp2    weekday_peak_1          6          2   45.0
# 5           2     shp2    weekday_peak_2          4          2   45.0
# 6           2     shp2   weekday_offpeak          2          1   45.0
# 7           2     shp2          saturday          2          0   45.0

# %%
f = (
    feed.routes[['route_id', 'route_short_name']]
    .merge(pfeed.frequencies)
    .merge(pfeed.service_windows)
    .sort_values('route_id')
)
f

# %%
# Map some trips
prefix = 't-rB-weekday_peak_1-07:00:00'
t = (
    feed.trips
    .loc[lambda x: x.trip_id.str.startswith(prefix)]
)
tids = [t.trip_id.iat[0], t.trip_id.iat[-1]]
feed.map_trips(tids, include_arrows=True)

# %%
#feed.write("../data/test_write_feed")
