# %%
import json
import sys

import pandas as pd
import numpy as np
import shapely
from shapely.ops import transform
from shapely.geometry import Point, shape, mapping
import utm

#home = '/Users/araichev/make_gtfs/'
home = '/home/araichev/make_gtfs/'

sys.path.append(home)
from feed import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'examples/test/'
feed = Feed(path)

# %%
# Create agency
feed.create_agency()
feed.agency
# Out:
#           agency_name   agency_timezone           agency_url
# 0  Auckland Transport  Pacific/Auckland  https://at.govt.nz/

# %%
feed.create_calendar()
feed.calendar
# Out:
#    end_date  friday  monday  saturday service_id start_date  sunday  thursday  \
# 0  20150101       1       1         1         c0   20140101       1         1
#
#    tuesday  wednesday
# 0        1          1

# %%
feed.create_routes()
feed.routes
# Out:
#   route_short_name                                         route_desc  \
# 0              010  City Link, Wynyard Quarter to Karangahape Rd v...
# 1              020  Inner Link. Britomart, Three Lamps, Ponsonby, ...
# 2              030  Grey Lynn to Auckland University via Richmond ...
# 3              031  St Lukes to Auckland University via Richmond R...
# 4              032  Westmere to Auckland University via Williamson...
# 5              033  Benson Rd to Karangahape Rd via Remuera, Hobso...
#
#    route_type  speed route_id
# 0           3     20       r0
# 1           3     20       r1
# 2           3     20       r2
# 3           3     20       r3
# 4           3     20       r4
# 5           3     20       r5

# %%
d = feed.get_service_window_duration_by_name()
d
# Out:
# {'weekday_night': 10,
#  'weekday_offpeak': 12,
#  'sunday_day': 14,
#  'sunday_night': 10,
#  'saturday_day': 14,
#  'saturday_night': 10,
#  'weekday_peak': 2}

# %%
feed.add_num_trips_per_direction()
feed.raw_routes
# Out:
#    unit_id      unit_name route_short_name  \
# 0        1      City LINK              010
# 1        2     Inner LINK              020
# 2        3  Richmond Road              030
# 3        3  Richmond Road              031
# 4        3  Richmond Road              032
# 5        3  Richmond Road              033
#
#                                           route_desc  weekday_peak_headway  \
# 0  City Link, Wynyard Quarter to Karangahape Rd v...                     5
# 1  Inner Link. Britomart, Three Lamps, Ponsonby, ...                    10
# 2  Grey Lynn to Auckland University via Richmond ...                    10
# 3  St Lukes to Auckland University via Richmond R...                    30
# 4  Westmere to Auckland University via Williamson...                    15
# 5  Benson Rd to Karangahape Rd via Remuera, Hobso...                    30
#
#    weekday_offpeak_headway  weekday_night_headway  saturday_day_headway  \
# 0                      7.5                     10                   7.5
# 1                     15.0                     15                  15.0
# 2                     15.0                     30                  30.0
# 3                     30.0                     30                  30.0
# 4                     30.0                     30                  30.0
# 5                     60.0                     60                  60.0
#
#    saturday_night_headway  sunday_day_headway  sunday_night_headway  \
# 0                      10                 7.5                    10
# 1                      15                15.0                    15
# 2                      30                30.0                    30
# 3                      30                30.0                    30
# 4                      30                30.0                    30
# 5                      60                60.0                    60
#
#    num_trips_per_direction
# 0                      524
# 1                      292
# 2                      176
# 3                      144
# 4                      148
# 5                       74

# %%
feed.create_shapes()
feed.shapes
# Out:
#     shape_id  shape_pt_sequence  shape_pt_lon  shape_pt_lat
# 0       s-r0                  0    174.767029    -36.844440
# 1       s-r0                  1    174.767401    -36.843364
# 2       s-r0                  2    174.768695    -36.843668
# 3       s-r0                  3    174.768113    -36.845003
# 4       s-r0                  4    174.767631    -36.844886
# 5       s-r0                  5    174.766853    -36.844619
# 6       s-r0                  6    174.765414    -36.849031
# 7       s-r0                  7    174.763086    -36.854224
# 8       s-r0                  8    174.762292    -36.853955
# 9       s-r0                  9    174.761962    -36.853794
# 10      s-r0                 10    174.758882    -36.856034
# 11      s-r0                 11    174.759072    -36.857619
# 12      s-r0                 12    174.760359    -36.857912
# 13      s-r0                 13    174.761580    -36.857914
# 14      s-r0                 14    174.765362    -36.848887
# 15      s-r0                 15    174.767029    -36.844440
# 16      s-r1                  0    174.744138    -36.847422
# 17      s-r1                  1    174.743802    -36.848536
# 18      s-r1                  2    174.744437    -36.850401
# 19      s-r1                  3    174.744949    -36.852240
# 20      s-r1                  4    174.745351    -36.853356
# 21      s-r1                  5    174.746586    -36.856383
# 22      s-r1                  6    174.749513    -36.857891
# 23      s-r1                  7    174.751020    -36.858745
# 24      s-r1                  8    174.752800    -36.859625
# 25      s-r1                  9    174.754449    -36.858743
# 26      s-r1                 10    174.758345    -36.857714
# 27      s-r1                 11    174.759975    -36.857934
# 28      s-r1                 12    174.762143    -36.857998
# 29      s-r1                 13    174.762377    -36.857951
# ..       ...                ...           ...           ...
# 188     s-r5                 46    174.796266    -36.864332
# 189     s-r5                 47    174.796057    -36.869880
# 190     s-r5                 48    174.795016    -36.872022
# 191     s-r5                 49    174.793710    -36.874369
# 192     s-r5                 50    174.793534    -36.876916
# 193     s-r5                 51    174.792132    -36.878138
# 194     s-r5                 52    174.792132    -36.879126
# 195     s-r5                 53    174.791957    -36.879468
# 196     s-r5                 54    174.793922    -36.880120
# 197     s-r5                 55    174.795005    -36.880445
# 198     s-r5                 56    174.798411    -36.880790
# 199     s-r5                 57    174.802646    -36.881171
# 200     s-r5                 58    174.803601    -36.878973
# 201     s-r5                 59    174.803845    -36.878279
# 202     s-r5                 60    174.803175    -36.875512
# 203     s-r5                 61    174.803801    -36.873947
# 204     s-r5                 62    174.804556    -36.873543
# 205     s-r5                 63    174.804932    -36.873094
# 206     s-r5                 64    174.807461    -36.872700
# 207     s-r5                 65    174.808938    -36.872679
# 208     s-r5                 66    174.809801    -36.873316
# 209     s-r5                 67    174.810851    -36.874252
# 210     s-r5                 68    174.812804    -36.875530
# 211     s-r5                 69    174.813968    -36.875701
# 212     s-r5                 70    174.813582    -36.877264
# 213     s-r5                 71    174.808934    -36.876616
# 214     s-r5                 72    174.808617    -36.876251
# 215     s-r5                 73    174.808918    -36.875324
# 216     s-r5                 74    174.809021    -36.874493
# 217     s-r5                 75    174.809914    -36.873762
#
# [218 rows x 4 columns]

# %%
feed.create_trips()
feed.trips
# Out:
#      route_id    trip_id  direction_id shape_id service_id
# 0          r0   t-r0-0-0             0     s-r0         c0
# 1          r0   t-r0-0-1             1     s-r0         c0
# 2          r0   t-r0-1-0             0     s-r0         c0
# 3          r0   t-r0-1-1             1     s-r0         c0
# 4          r0   t-r0-2-0             0     s-r0         c0
# 5          r0   t-r0-2-1             1     s-r0         c0
# 6          r0   t-r0-3-0             0     s-r0         c0
# 7          r0   t-r0-3-1             1     s-r0         c0
# 8          r0   t-r0-4-0             0     s-r0         c0
# 9          r0   t-r0-4-1             1     s-r0         c0
# 10         r0   t-r0-5-0             0     s-r0         c0
# 11         r0   t-r0-5-1             1     s-r0         c0
# 12         r0   t-r0-6-0             0     s-r0         c0
# 13         r0   t-r0-6-1             1     s-r0         c0
# 14         r0   t-r0-7-0             0     s-r0         c0
# 15         r0   t-r0-7-1             1     s-r0         c0
# 16         r0   t-r0-8-0             0     s-r0         c0
# 17         r0   t-r0-8-1             1     s-r0         c0
# 18         r0   t-r0-9-0             0     s-r0         c0
# 19         r0   t-r0-9-1             1     s-r0         c0
# 20         r0  t-r0-10-0             0     s-r0         c0
# 21         r0  t-r0-10-1             1     s-r0         c0
# 22         r0  t-r0-11-0             0     s-r0         c0
# 23         r0  t-r0-11-1             1     s-r0         c0
# 24         r0  t-r0-12-0             0     s-r0         c0
# 25         r0  t-r0-12-1             1     s-r0         c0
# 26         r0  t-r0-13-0             0     s-r0         c0
# 27         r0  t-r0-13-1             1     s-r0         c0
# 28         r0  t-r0-14-0             0     s-r0         c0
# 29         r0  t-r0-14-1             1     s-r0         c0
# ...       ...        ...           ...      ...        ...
# 2686       r5  t-r5-59-0             0     s-r5         c0
# 2687       r5  t-r5-59-1             1     s-r5         c0
# 2688       r5  t-r5-60-0             0     s-r5         c0
# 2689       r5  t-r5-60-1             1     s-r5         c0
# 2690       r5  t-r5-61-0             0     s-r5         c0
# 2691       r5  t-r5-61-1             1     s-r5         c0
# 2692       r5  t-r5-62-0             0     s-r5         c0
# 2693       r5  t-r5-62-1             1     s-r5         c0
# 2694       r5  t-r5-63-0             0     s-r5         c0
# 2695       r5  t-r5-63-1             1     s-r5         c0
# 2696       r5  t-r5-64-0             0     s-r5         c0
# 2697       r5  t-r5-64-1             1     s-r5         c0
# 2698       r5  t-r5-65-0             0     s-r5         c0
# 2699       r5  t-r5-65-1             1     s-r5         c0
# 2700       r5  t-r5-66-0             0     s-r5         c0
# 2701       r5  t-r5-66-1             1     s-r5         c0
# 2702       r5  t-r5-67-0             0     s-r5         c0
# 2703       r5  t-r5-67-1             1     s-r5         c0
# 2704       r5  t-r5-68-0             0     s-r5         c0
# 2705       r5  t-r5-68-1             1     s-r5         c0
# 2706       r5  t-r5-69-0             0     s-r5         c0
# 2707       r5  t-r5-69-1             1     s-r5         c0
# 2708       r5  t-r5-70-0             0     s-r5         c0
# 2709       r5  t-r5-70-1             1     s-r5         c0
# 2710       r5  t-r5-71-0             0     s-r5         c0
# 2711       r5  t-r5-71-1             1     s-r5         c0
# 2712       r5  t-r5-72-0             0     s-r5         c0
# 2713       r5  t-r5-72-1             1     s-r5         c0
# 2714       r5  t-r5-73-0             0     s-r5         c0
# 2715       r5  t-r5-73-1             1     s-r5         c0
#
# [2716 rows x 5 columns]

# %%
feed.create_stops()
feed.stops
# Out:
#     stop_id                stop_name    stop_lon   stop_lat
# 0   st-r0-0  First stop on route 010  174.767029 -36.844440
# 1   st-r0-1   Last stop on route 010  174.767029 -36.844440
# 2   st-r2-0  First stop on route 030  174.768581 -36.851434
# 3   st-r2-1   Last stop on route 030  174.737459 -36.864505
# 4   st-r5-0  First stop on route 033  174.759375 -36.857818
# 5   st-r5-1   Last stop on route 033  174.809914 -36.873762
# 6   st-r3-0  First stop on route 031  174.737212 -36.864404
# 7   st-r3-1   Last stop on route 031  174.735337 -36.884476
# 8   st-r4-0  First stop on route 032  174.766889 -36.844595
# 9   st-r4-1   Last stop on route 032  174.723916 -36.851549
# 10  st-r1-0  First stop on route 020  174.744138 -36.847422
# 11  st-r1-1   Last stop on route 020  174.744298 -36.847422
