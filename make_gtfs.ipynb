# %%
import json
import sys

import pandas as pd
import numpy as np
import shapely
from shapely.ops import transform
from shapely.geometry import Point, shape, mapping
import utm

home = '/Users/araichev/make_gtfs/'
sys.path.append(home)
from feed import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = 'examples/test/'
feed = Feed(path)

# %%
# Create agency
feed.create_agency()
feed.agency
# Out:
#           agency_name   agency_timezone           agency_url
# 0  Auckland Transport  Pacific/Auckland  https://at.govt.nz/

# %%
# Create routes
feed.create_routes()
feed.routes
# Out:
#   route_short_name                                         route_desc  \
# 0              010  City Link, Wynyard Quarter to Karangahape Rd v...
# 1              020  Inner Link. Britomart, Three Lamps, Ponsonby, ...
# 2              030  Grey Lynn to Auckland University via Richmond ...
# 3              031  St Lukes to Auckland University via Richmond R...
# 4              032  Westmere to Auckland University via Williamson...
# 5              033  Benson Rd to Karangahape Rd via Remuera, Hobso...
#
#    route_type route_id
# 0           3       r0
# 1           3       r1
# 2           3       r2
# 3           3       r3
# 4           3       r4
# 5           3       r5

# %%
d = feed.get_service_window_duration_by_name()
d
# Out:
# {'weekday_offpeak': 12,
#  'saturday_day': 14,
#  'weekday_night': 10,
#  'sunday_night': 10,
#  'weekday_peak': 2,
#  'sunday_day': 14,
#  'saturday_night': 10}

# %%
feed.add_num_trips()
feed.raw_routes
# Out:
#    unit_id      unit_name route_short_name  \
# 0        1      City LINK              010
# 1        2     Inner LINK              020
# 2        3  Richmond Road              030
# 3        3  Richmond Road              031
# 4        3  Richmond Road              032
# 5        3  Richmond Road              033
#
#                                           route_desc  route_type  \
# 0  City Link, Wynyard Quarter to Karangahape Rd v...           3
# 1  Inner Link. Britomart, Three Lamps, Ponsonby, ...           3
# 2  Grey Lynn to Auckland University via Richmond ...         NaN
# 3  St Lukes to Auckland University via Richmond R...         NaN
# 4  Westmere to Auckland University via Williamson...           3
# 5  Benson Rd to Karangahape Rd via Remuera, Hobso...         NaN
#
#    weekday_peak_headway  weekday_offpeak_headway  weekday_night_headway  \
# 0                     5                      7.5                     10
# 1                    10                     15.0                     15
# 2                    10                     15.0                     30
# 3                    30                     30.0                     30
# 4                    15                     30.0                     30
# 5                    30                     60.0                     60
#
#    saturday_day_headway  saturday_night_headway  sunday_day_headway  \
# 0                   7.5                      10                 7.5
# 1                  15.0                      15                15.0
# 2                  30.0                      30                30.0
# 3                  30.0                      30                30.0
# 4                  30.0                      30                30.0
# 5                  60.0                      60                60.0
#
#    sunday_night_headway  num_trips
# 0                    10        524
# 1                    15        292
# 2                    30        176
# 3                    30        144
# 4                    30        148
# 5                    60         74

# %%
# Convert shapes to Shapely linestrings in UTM coordinates
def get_linestring_by_route(collection, use_utm=True):
    """
    Given a GeoJSON feature collection of linestrings tagged with route IDs,
    return a dictionary with structure
    route_id -> Shapely linestring of shape.
    If ``use_utm == True``, then return each linestring in
    in UTM coordinates.
    Otherwise, return each linestring in WGS84 longitude-latitude
    coordinates.
    """
    # Note the output for conversion to UTM with the utm package:
    # >>> u = utm.from_latlon(47.9941214, 7.8509671)
    # >>> print u
    # (414278, 5316285, 32, 'T')
    d = {}
    if use_utm:
        def proj(lon, lat):
            return utm.from_latlon(lat, lon)[:2] 
    else:
        def proj(lon, lat):
            return lon, lat
        
    return {f['properties']['route_short_name']: transform(proj, shape(f['geometry']))
      for f in collection['features']}

linestring_by_route = get_linestring_by_route(shapes)
print(len(linestring_by_route))
linestring_by_route['010']
# Out:
# 6
# [autoreload of feed failed: Traceback (most recent call last):
#   File "/Users/araichev/.virtualenvs/make_gtfs/lib/python3.4/site-packages/IPython/extensions/autoreload.py", line 247, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/araichev/make_gtfs/feed.py", line 120
#     for windows, name in sw_by_name.items()
#                                           ^
# SyntaxError: invalid syntax
# ]
