# %%
import os
import sys

home = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
print(home)
sys.path.append(home)
from make_gtfs.make_gtfs import *

# %load_ext autoreload
# %autoreload 2
# Out:
# /home/araichev/make_gtfs
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = home + '/data/auckland/'
feed = Feed(path)

# %%
# Create agency
feed.create_agency()
feed.agency
# Out:
#           agency_name   agency_timezone           agency_url
# 0  Auckland Transport  Pacific/Auckland  https://at.govt.nz/

# %%
feed.create_calendar()
feed.calendar
# Out:
#    service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0  srv1111100       1        1          1         1       1         0       0
# 1  srv0000010       0        0          0         0       0         1       0
#
#   start_date end_date
# 0   20140101  2015010
# 1   20140101  2015010

# %%
feed.create_routes()
feed.routes
# Out:
#   route_short_name                                         route_desc  \
# 0                1  City Link, Wynyard Quarter to Karangahape Rd v...
# 4                2  Inner Link. Britomart, Three Lamps, Ponsonby, ...
#
#    route_type route_id
# 0           3       r0
# 4           2       r1

# %%
feed.create_shapes()
feed.shapes
# Out:
#    shape_id  shape_pt_sequence  shape_pt_lon  shape_pt_lat
# 0      shp1                  0    174.767029    -36.844440
# 1      shp1                  1    174.767401    -36.843364
# 2      shp1                  2    174.768695    -36.843668
# 3      shp1                  3    174.768113    -36.845003
# 4      shp1                  4    174.767631    -36.844886
# 5      shp1                  5    174.766853    -36.844619
# 6      shp1                  6    174.765414    -36.849031
# 7      shp1                  7    174.763086    -36.854224
# 8      shp1                  8    174.762292    -36.853955
# 9      shp1                  9    174.761962    -36.853794
# 10     shp1                 10    174.758882    -36.856034
# 11     shp1                 11    174.759072    -36.857619
# 12     shp1                 12    174.760359    -36.857912
# 13     shp1                 13    174.761580    -36.857914
# 14     shp1                 14    174.765362    -36.848887
# 15     shp1                 15    174.767029    -36.844440
# 16     shp2                  0    174.744138    -36.847422
# 17     shp2                  1    174.743802    -36.848536
# 18     shp2                  2    174.744437    -36.850401
# 19     shp2                  3    174.744949    -36.852240
# 20     shp2                  4    174.745351    -36.853356
# 21     shp2                  5    174.746586    -36.856383
# 22     shp2                  6    174.749513    -36.857891
# 23     shp2                  7    174.751020    -36.858745
# 24     shp2                  8    174.752800    -36.859625
# 25     shp2                  9    174.754449    -36.858743
# 26     shp2                 10    174.758345    -36.857714
# 27     shp2                 11    174.759975    -36.857934
# 28     shp2                 12    174.762143    -36.857998
# 29     shp2                 13    174.762377    -36.857951
# ..      ...                ...           ...           ...
# 41     shp2                 25    174.781841    -36.861990
# 42     shp2                 26    174.782643    -36.860773
# 43     shp2                 27    174.782887    -36.858941
# 44     shp2                 28    174.781213    -36.856564
# 45     shp2                 29    174.778722    -36.852603
# 46     shp2                 30    174.778063    -36.851994
# 47     shp2                 31    174.775938    -36.851178
# 48     shp2                 32    174.774518    -36.850486
# 49     shp2                 33    174.774569    -36.849787
# 50     shp2                 34    174.774394    -36.848658
# 51     shp2                 35    174.773665    -36.847417
# 52     shp2                 36    174.772680    -36.846450
# 53     shp2                 37    174.771760    -36.845896
# 54     shp2                 38    174.770930    -36.845632
# 55     shp2                 39    174.769794    -36.845490
# 56     shp2                 40    174.767472    -36.844944
# 57     shp2                 41    174.765344    -36.844280
# 58     shp2                 42    174.764025    -36.844294
# 59     shp2                 43    174.762390    -36.844776
# 60     shp2                 44    174.761424    -36.845411
# 61     shp2                 45    174.759115    -36.845826
# 62     shp2                 46    174.756675    -36.846161
# 63     shp2                 47    174.752991    -36.845157
# 64     shp2                 48    174.751725    -36.847100
# 65     shp2                 49    174.751048    -36.848250
# 66     shp2                 50    174.749652    -36.848449
# 67     shp2                 51    174.747900    -36.848519
# 68     shp2                 52    174.746635    -36.847883
# 69     shp2                 53    174.745532    -36.847517
# 70     shp2                 54    174.744298    -36.847422
#
# [71 rows x 4 columns]

# %%
feed.create_stops()
feed.stops
# Out:
#     stop_id       stop_name    stop_lon   stop_lat
# 0  stp#r0#0  Route 1 stop 0  174.767029 -36.844440
# 1  stp#r0#1  Route 1 stop 1  174.767029 -36.844440
# 2  stp#r1#0  Route 2 stop 0  174.744138 -36.847422
# 3  stp#r1#1  Route 2 stop 1  174.744298 -36.847422

# %%
f = pd.merge(feed.routes[['route_id', 'route_short_name']], feed.proto_routes)
f = pd.merge(f, feed.service_windows)
f.T
# Out:
#                                                                    0  \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# start_time                                                  07:00:00
# end_time                                                    09:00:00
# monday                                                             1
# tuesday                                                            1
# wednesday                                                          1
# thursday                                                           1
# friday                                                             1
# saturday                                                           0
# sunday                                                             0
#
#                                                                    1  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                     weekday_peak_1
# frequency                                                          6
# is_bidirectional                                                   1
# speed                                                             20
# start_time                                                  07:00:00
# end_time                                                    09:00:00
# monday                                                             1
# tuesday                                                            1
# wednesday                                                          1
# thursday                                                           1
# friday                                                             1
# saturday                                                           0
# sunday                                                             0
#
#                                                                    2  \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_2
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# start_time                                                  15:00:00
# end_time                                                    17:00:00
# monday                                                             1
# tuesday                                                            1
# wednesday                                                          1
# thursday                                                           1
# friday                                                             1
# saturday                                                           0
# sunday                                                             0
#
#                                                                    3  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                     weekday_peak_2
# frequency                                                          4
# is_bidirectional                                                   1
# speed                                                             20
# start_time                                                  15:00:00
# end_time                                                    17:00:00
# monday                                                             1
# tuesday                                                            1
# wednesday                                                          1
# thursday                                                           1
# friday                                                             1
# saturday                                                           0
# sunday                                                             0
#
#                                                                    4  \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                    weekday_offpeak
# frequency                                                          4
# is_bidirectional                                                   0
# speed                                                             20
# start_time                                                  09:00:00
# end_time                                                    15:00:00
# monday                                                             1
# tuesday                                                            1
# wednesday                                                          1
# thursday                                                           1
# friday                                                             1
# saturday                                                           0
# sunday                                                             0
#
#                                                                    5  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                    weekday_offpeak
# frequency                                                          2
# is_bidirectional                                                   1
# speed                                                             20
# start_time                                                  09:00:00
# end_time                                                    15:00:00
# monday                                                             1
# tuesday                                                            1
# wednesday                                                          1
# thursday                                                           1
# friday                                                             1
# saturday                                                           0
# sunday                                                             0
#
#                                                                    6  \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                           saturday
# frequency                                                          6
# is_bidirectional                                                   0
# speed                                                             20
# start_time                                                  09:00:00
# end_time                                                    19:00:00
# monday                                                             0
# tuesday                                                            0
# wednesday                                                          0
# thursday                                                           0
# friday                                                             0
# saturday                                                           1
# sunday                                                             0
#
#                                                                    7
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# start_time                                                  09:00:00
# end_time                                                    19:00:00
# monday                                                             0
# tuesday                                                            0
# wednesday                                                          0
# thursday                                                           0
# friday                                                             0
# saturday                                                           1
# sunday                                                             0

# %%
feed.create_trips()
feed.trips
# Out:
# r0 weekday_peak_1 2.0 12 1 24
# r1 weekday_peak_1 2.0 6 1 12
# r0 weekday_peak_2 2.0 12 1 24
# r1 weekday_peak_2 2.0 4 1 8
# r0 weekday_offpeak 6.0 4 0 24
# r1 weekday_offpeak 6.0 2 1 12
# r0 saturday 10.0 6 0 60
# r1 saturday 10.0 2 0 20
# expect num trips = 264.0
#     route_id                            trip_id  direction_id shape_id  \
# 0         r0   t#r0#weekday_peak_1#07:00:00#0#0             0     shp1
# 1         r0   t#r0#weekday_peak_1#07:00:00#0#1             0     shp1
# 2         r0   t#r0#weekday_peak_1#07:00:00#0#2             0     shp1
# 3         r0   t#r0#weekday_peak_1#07:00:00#0#3             0     shp1
# 4         r0   t#r0#weekday_peak_1#07:00:00#0#4             0     shp1
# 5         r0   t#r0#weekday_peak_1#07:00:00#0#5             0     shp1
# 6         r0   t#r0#weekday_peak_1#07:00:00#0#6             0     shp1
# 7         r0   t#r0#weekday_peak_1#07:00:00#0#7             0     shp1
# 8         r0   t#r0#weekday_peak_1#07:00:00#0#8             0     shp1
# 9         r0   t#r0#weekday_peak_1#07:00:00#0#9             0     shp1
# 10        r0  t#r0#weekday_peak_1#07:00:00#0#10             0     shp1
# 11        r0  t#r0#weekday_peak_1#07:00:00#0#11             0     shp1
# 12        r0  t#r0#weekday_peak_1#07:00:00#0#12             0     shp1
# 13        r0  t#r0#weekday_peak_1#07:00:00#0#13             0     shp1
# 14        r0  t#r0#weekday_peak_1#07:00:00#0#14             0     shp1
# 15        r0  t#r0#weekday_peak_1#07:00:00#0#15             0     shp1
# 16        r0  t#r0#weekday_peak_1#07:00:00#0#16             0     shp1
# 17        r0  t#r0#weekday_peak_1#07:00:00#0#17             0     shp1
# 18        r0  t#r0#weekday_peak_1#07:00:00#0#18             0     shp1
# 19        r0  t#r0#weekday_peak_1#07:00:00#0#19             0     shp1
# 20        r0  t#r0#weekday_peak_1#07:00:00#0#20             0     shp1
# 21        r0  t#r0#weekday_peak_1#07:00:00#0#21             0     shp1
# 22        r0  t#r0#weekday_peak_1#07:00:00#0#22             0     shp1
# 23        r0  t#r0#weekday_peak_1#07:00:00#0#23             0     shp1
# 24        r0   t#r0#weekday_peak_1#07:00:00#1#0             1     shp1
# 25        r0   t#r0#weekday_peak_1#07:00:00#1#1             1     shp1
# 26        r0   t#r0#weekday_peak_1#07:00:00#1#2             1     shp1
# 27        r0   t#r0#weekday_peak_1#07:00:00#1#3             1     shp1
# 28        r0   t#r0#weekday_peak_1#07:00:00#1#4             1     shp1
# 29        r0   t#r0#weekday_peak_1#07:00:00#1#5             1     shp1
# ..       ...                                ...           ...      ...
# 234       r0        t#r0#saturday#09:00:00#0#50             0     shp1
# 235       r0        t#r0#saturday#09:00:00#0#51             0     shp1
# 236       r0        t#r0#saturday#09:00:00#0#52             0     shp1
# 237       r0        t#r0#saturday#09:00:00#0#53             0     shp1
# 238       r0        t#r0#saturday#09:00:00#0#54             0     shp1
# 239       r0        t#r0#saturday#09:00:00#0#55             0     shp1
# 240       r0        t#r0#saturday#09:00:00#0#56             0     shp1
# 241       r0        t#r0#saturday#09:00:00#0#57             0     shp1
# 242       r0        t#r0#saturday#09:00:00#0#58             0     shp1
# 243       r0        t#r0#saturday#09:00:00#0#59             0     shp1
# 244       r1         t#r1#saturday#09:00:00#0#0             0     shp2
# 245       r1         t#r1#saturday#09:00:00#0#1             0     shp2
# 246       r1         t#r1#saturday#09:00:00#0#2             0     shp2
# 247       r1         t#r1#saturday#09:00:00#0#3             0     shp2
# 248       r1         t#r1#saturday#09:00:00#0#4             0     shp2
# 249       r1         t#r1#saturday#09:00:00#0#5             0     shp2
# 250       r1         t#r1#saturday#09:00:00#0#6             0     shp2
# 251       r1         t#r1#saturday#09:00:00#0#7             0     shp2
# 252       r1         t#r1#saturday#09:00:00#0#8             0     shp2
# 253       r1         t#r1#saturday#09:00:00#0#9             0     shp2
# 254       r1        t#r1#saturday#09:00:00#0#10             0     shp2
# 255       r1        t#r1#saturday#09:00:00#0#11             0     shp2
# 256       r1        t#r1#saturday#09:00:00#0#12             0     shp2
# 257       r1        t#r1#saturday#09:00:00#0#13             0     shp2
# 258       r1        t#r1#saturday#09:00:00#0#14             0     shp2
# 259       r1        t#r1#saturday#09:00:00#0#15             0     shp2
# 260       r1        t#r1#saturday#09:00:00#0#16             0     shp2
# 261       r1        t#r1#saturday#09:00:00#0#17             0     shp2
# 262       r1        t#r1#saturday#09:00:00#0#18             0     shp2
# 263       r1        t#r1#saturday#09:00:00#0#19             0     shp2
#
#      service_id
# 0    srv1111100
# 1    srv1111100
# 2    srv1111100
# 3    srv1111100
# 4    srv1111100
# 5    srv1111100
# 6    srv1111100
# 7    srv1111100
# 8    srv1111100
# 9    srv1111100
# 10   srv1111100
# 11   srv1111100
# 12   srv1111100
# 13   srv1111100
# 14   srv1111100
# 15   srv1111100
# 16   srv1111100
# 17   srv1111100
# 18   srv1111100
# 19   srv1111100
# 20   srv1111100
# 21   srv1111100
# 22   srv1111100
# 23   srv1111100
# 24   srv1111100
# 25   srv1111100
# 26   srv1111100
# 27   srv1111100
# 28   srv1111100
# 29   srv1111100
# ..          ...
# 234  srv0000010
# 235  srv0000010
# 236  srv0000010
# 237  srv0000010
# 238  srv0000010
# 239  srv0000010
# 240  srv0000010
# 241  srv0000010
# 242  srv0000010
# 243  srv0000010
# 244  srv0000010
# 245  srv0000010
# 246  srv0000010
# 247  srv0000010
# 248  srv0000010
# 249  srv0000010
# 250  srv0000010
# 251  srv0000010
# 252  srv0000010
# 253  srv0000010
# 254  srv0000010
# 255  srv0000010
# 256  srv0000010
# 257  srv0000010
# 258  srv0000010
# 259  srv0000010
# 260  srv0000010
# 261  srv0000010
# 262  srv0000010
# 263  srv0000010
#
# [264 rows x 5 columns]

# %%
f = feed.trips.copy()
f['service_window_id'] = f['trip_id'].map(lambda x: x.split('#')[2])
f
g = pd.merge(pd.merge(feed.routes[['route_id', 'route_short_name']], feed.proto_routes), f)
print(g.shape[0])
g.T
# Out:
# 264
#                                                                  0    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#0
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  1    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#1
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  2    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#2
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  3    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#3
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  4    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#4
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  5    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#5
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  6    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#6
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  7    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#7
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  8    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#8
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                                                  9    \
# route_id                                                          r0
# route_short_name                                                   1
# route_desc         City Link, Wynyard Quarter to Karangahape Rd v...
# route_type                                                         3
# shape_id                                                        shp1
# service_window_id                                     weekday_peak_1
# frequency                                                         12
# is_bidirectional                                                   1
# speed                                                             20
# trip_id                             t#r0#weekday_peak_1#07:00:00#0#9
# direction_id                                                       0
# service_id                                                srv1111100
#
#                                          ...                          \
# route_id                                 ...
# route_short_name                         ...
# route_desc                               ...
# route_type                               ...
# shape_id                                 ...
# service_window_id                        ...
# frequency                                ...
# is_bidirectional                         ...
# speed                                    ...
# trip_id                                  ...
# direction_id                             ...
# service_id                               ...
#
#                                                                  254  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#10
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  255  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#11
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  256  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#12
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  257  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#13
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  258  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#14
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  259  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#15
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  260  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#16
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  261  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#17
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  262  \
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#18
# direction_id                                                       0
# service_id                                                srv0000010
#
#                                                                  263
# route_id                                                          r1
# route_short_name                                                   2
# route_desc         Inner Link. Britomart, Three Lamps, Ponsonby, ...
# route_type                                                         2
# shape_id                                                        shp2
# service_window_id                                           saturday
# frequency                                                          2
# is_bidirectional                                                   0
# speed                                                             20
# trip_id                                  t#r1#saturday#09:00:00#0#19
# direction_id                                                       0
# service_id                                                srv0000010
#
# [12 rows x 264 columns]

# %%
feed.create_stop_times()
feed.stop_times
# Out:
#                                trip_id   stop_id  stop_sequence arrival_time  \
# 0     t#r0#weekday_peak_1#07:00:00#0#0  stp#r0#0              0     07:00:00
# 1     t#r0#weekday_peak_1#07:00:00#0#0  stp#r0#1              1     07:12:17
# 2     t#r0#weekday_peak_1#07:00:00#0#1  stp#r0#0              0     07:05:00
# 3     t#r0#weekday_peak_1#07:00:00#0#1  stp#r0#1              1     07:17:17
# 4     t#r0#weekday_peak_1#07:00:00#0#2  stp#r0#0              0     07:10:00
# 5     t#r0#weekday_peak_1#07:00:00#0#2  stp#r0#1              1     07:22:17
# 6     t#r0#weekday_peak_1#07:00:00#0#3  stp#r0#0              0     07:15:00
# 7     t#r0#weekday_peak_1#07:00:00#0#3  stp#r0#1              1     07:27:17
# 8     t#r0#weekday_peak_1#07:00:00#0#4  stp#r0#0              0     07:20:00
# 9     t#r0#weekday_peak_1#07:00:00#0#4  stp#r0#1              1     07:32:17
# 10    t#r0#weekday_peak_1#07:00:00#0#5  stp#r0#0              0     07:25:00
# 11    t#r0#weekday_peak_1#07:00:00#0#5  stp#r0#1              1     07:37:17
# 12    t#r0#weekday_peak_1#07:00:00#0#6  stp#r0#0              0     07:30:00
# 13    t#r0#weekday_peak_1#07:00:00#0#6  stp#r0#1              1     07:42:17
# 14    t#r0#weekday_peak_1#07:00:00#0#7  stp#r0#0              0     07:35:00
# 15    t#r0#weekday_peak_1#07:00:00#0#7  stp#r0#1              1     07:47:17
# 16    t#r0#weekday_peak_1#07:00:00#0#8  stp#r0#0              0     07:40:00
# 17    t#r0#weekday_peak_1#07:00:00#0#8  stp#r0#1              1     07:52:17
# 18    t#r0#weekday_peak_1#07:00:00#0#9  stp#r0#0              0     07:45:00
# 19    t#r0#weekday_peak_1#07:00:00#0#9  stp#r0#1              1     07:57:17
# 20   t#r0#weekday_peak_1#07:00:00#0#10  stp#r0#0              0     07:50:00
# 21   t#r0#weekday_peak_1#07:00:00#0#10  stp#r0#1              1     08:02:17
# 22   t#r0#weekday_peak_1#07:00:00#0#11  stp#r0#0              0     07:55:00
# 23   t#r0#weekday_peak_1#07:00:00#0#11  stp#r0#1              1     08:07:17
# 24   t#r0#weekday_peak_1#07:00:00#0#12  stp#r0#0              0     08:00:00
# 25   t#r0#weekday_peak_1#07:00:00#0#12  stp#r0#1              1     08:12:17
# 26   t#r0#weekday_peak_1#07:00:00#0#13  stp#r0#0              0     08:05:00
# 27   t#r0#weekday_peak_1#07:00:00#0#13  stp#r0#1              1     08:17:17
# 28   t#r0#weekday_peak_1#07:00:00#0#14  stp#r0#0              0     08:10:00
# 29   t#r0#weekday_peak_1#07:00:00#0#14  stp#r0#1              1     08:22:17
# ..                                 ...       ...            ...          ...
# 498         t#r1#saturday#09:00:00#0#5  stp#r1#0              0     11:30:00
# 499         t#r1#saturday#09:00:00#0#5  stp#r1#1              1     12:00:59
# 500         t#r1#saturday#09:00:00#0#6  stp#r1#0              0     12:00:00
# 501         t#r1#saturday#09:00:00#0#6  stp#r1#1              1     12:30:59
# 502         t#r1#saturday#09:00:00#0#7  stp#r1#0              0     12:30:00
# 503         t#r1#saturday#09:00:00#0#7  stp#r1#1              1     13:00:59
# 504         t#r1#saturday#09:00:00#0#8  stp#r1#0              0     13:00:00
# 505         t#r1#saturday#09:00:00#0#8  stp#r1#1              1     13:30:59
# 506         t#r1#saturday#09:00:00#0#9  stp#r1#0              0     13:30:00
# 507         t#r1#saturday#09:00:00#0#9  stp#r1#1              1     14:00:59
# 508        t#r1#saturday#09:00:00#0#10  stp#r1#0              0     14:00:00
# 509        t#r1#saturday#09:00:00#0#10  stp#r1#1              1     14:30:59
# 510        t#r1#saturday#09:00:00#0#11  stp#r1#0              0     14:30:00
# 511        t#r1#saturday#09:00:00#0#11  stp#r1#1              1     15:00:59
# 512        t#r1#saturday#09:00:00#0#12  stp#r1#0              0     15:00:00
# 513        t#r1#saturday#09:00:00#0#12  stp#r1#1              1     15:30:59
# 514        t#r1#saturday#09:00:00#0#13  stp#r1#0              0     15:30:00
# 515        t#r1#saturday#09:00:00#0#13  stp#r1#1              1     16:00:59
# 516        t#r1#saturday#09:00:00#0#14  stp#r1#0              0     16:00:00
# 517        t#r1#saturday#09:00:00#0#14  stp#r1#1              1     16:30:59
# 518        t#r1#saturday#09:00:00#0#15  stp#r1#0              0     16:30:00
# 519        t#r1#saturday#09:00:00#0#15  stp#r1#1              1     17:00:59
# 520        t#r1#saturday#09:00:00#0#16  stp#r1#0              0     17:00:00
# 521        t#r1#saturday#09:00:00#0#16  stp#r1#1              1     17:30:59
# 522        t#r1#saturday#09:00:00#0#17  stp#r1#0              0     17:30:00
# 523        t#r1#saturday#09:00:00#0#17  stp#r1#1              1     18:00:59
# 524        t#r1#saturday#09:00:00#0#18  stp#r1#0              0     18:00:00
# 525        t#r1#saturday#09:00:00#0#18  stp#r1#1              1     18:30:59
# 526        t#r1#saturday#09:00:00#0#19  stp#r1#0              0     18:30:00
# 527        t#r1#saturday#09:00:00#0#19  stp#r1#1              1     19:00:59
#
#     departure_time
# 0         07:00:00
# 1         07:12:17
# 2         07:05:00
# 3         07:17:17
# 4         07:10:00
# 5         07:22:17
# 6         07:15:00
# 7         07:27:17
# 8         07:20:00
# 9         07:32:17
# 10        07:25:00
# 11        07:37:17
# 12        07:30:00
# 13        07:42:17
# 14        07:35:00
# 15        07:47:17
# 16        07:40:00
# 17        07:52:17
# 18        07:45:00
# 19        07:57:17
# 20        07:50:00
# 21        08:02:17
# 22        07:55:00
# 23        08:07:17
# 24        08:00:00
# 25        08:12:17
# 26        08:05:00
# 27        08:17:17
# 28        08:10:00
# 29        08:22:17
# ..             ...
# 498       11:30:00
# 499       12:00:59
# 500       12:00:00
# 501       12:30:59
# 502       12:30:00
# 503       13:00:59
# 504       13:00:00
# 505       13:30:59
# 506       13:30:00
# 507       14:00:59
# 508       14:00:00
# 509       14:30:59
# 510       14:30:00
# 511       15:00:59
# 512       15:00:00
# 513       15:30:59
# 514       15:30:00
# 515       16:00:59
# 516       16:00:00
# 517       16:30:59
# 518       16:30:00
# 519       17:00:59
# 520       17:00:00
# 521       17:30:59
# 522       17:30:00
# 523       18:00:59
# 524       18:00:00
# 525       18:30:59
# 526       18:30:00
# 527       19:00:59
#
# [528 rows x 5 columns]

# %%
f = feed.stop_times
f[f['trip_id'].str.contains('r1#saturday')]
# Out:
#                          trip_id   stop_id  stop_sequence arrival_time  \
# 488   t#r1#saturday#09:00:00#0#0  stp#r1#0              0     09:00:00
# 489   t#r1#saturday#09:00:00#0#0  stp#r1#1              1     09:30:59
# 490   t#r1#saturday#09:00:00#0#1  stp#r1#0              0     09:30:00
# 491   t#r1#saturday#09:00:00#0#1  stp#r1#1              1     10:00:59
# 492   t#r1#saturday#09:00:00#0#2  stp#r1#0              0     10:00:00
# 493   t#r1#saturday#09:00:00#0#2  stp#r1#1              1     10:30:59
# 494   t#r1#saturday#09:00:00#0#3  stp#r1#0              0     10:30:00
# 495   t#r1#saturday#09:00:00#0#3  stp#r1#1              1     11:00:59
# 496   t#r1#saturday#09:00:00#0#4  stp#r1#0              0     11:00:00
# 497   t#r1#saturday#09:00:00#0#4  stp#r1#1              1     11:30:59
# 498   t#r1#saturday#09:00:00#0#5  stp#r1#0              0     11:30:00
# 499   t#r1#saturday#09:00:00#0#5  stp#r1#1              1     12:00:59
# 500   t#r1#saturday#09:00:00#0#6  stp#r1#0              0     12:00:00
# 501   t#r1#saturday#09:00:00#0#6  stp#r1#1              1     12:30:59
# 502   t#r1#saturday#09:00:00#0#7  stp#r1#0              0     12:30:00
# 503   t#r1#saturday#09:00:00#0#7  stp#r1#1              1     13:00:59
# 504   t#r1#saturday#09:00:00#0#8  stp#r1#0              0     13:00:00
# 505   t#r1#saturday#09:00:00#0#8  stp#r1#1              1     13:30:59
# 506   t#r1#saturday#09:00:00#0#9  stp#r1#0              0     13:30:00
# 507   t#r1#saturday#09:00:00#0#9  stp#r1#1              1     14:00:59
# 508  t#r1#saturday#09:00:00#0#10  stp#r1#0              0     14:00:00
# 509  t#r1#saturday#09:00:00#0#10  stp#r1#1              1     14:30:59
# 510  t#r1#saturday#09:00:00#0#11  stp#r1#0              0     14:30:00
# 511  t#r1#saturday#09:00:00#0#11  stp#r1#1              1     15:00:59
# 512  t#r1#saturday#09:00:00#0#12  stp#r1#0              0     15:00:00
# 513  t#r1#saturday#09:00:00#0#12  stp#r1#1              1     15:30:59
# 514  t#r1#saturday#09:00:00#0#13  stp#r1#0              0     15:30:00
# 515  t#r1#saturday#09:00:00#0#13  stp#r1#1              1     16:00:59
# 516  t#r1#saturday#09:00:00#0#14  stp#r1#0              0     16:00:00
# 517  t#r1#saturday#09:00:00#0#14  stp#r1#1              1     16:30:59
# 518  t#r1#saturday#09:00:00#0#15  stp#r1#0              0     16:30:00
# 519  t#r1#saturday#09:00:00#0#15  stp#r1#1              1     17:00:59
# 520  t#r1#saturday#09:00:00#0#16  stp#r1#0              0     17:00:00
# 521  t#r1#saturday#09:00:00#0#16  stp#r1#1              1     17:30:59
# 522  t#r1#saturday#09:00:00#0#17  stp#r1#0              0     17:30:00
# 523  t#r1#saturday#09:00:00#0#17  stp#r1#1              1     18:00:59
# 524  t#r1#saturday#09:00:00#0#18  stp#r1#0              0     18:00:00
# 525  t#r1#saturday#09:00:00#0#18  stp#r1#1              1     18:30:59
# 526  t#r1#saturday#09:00:00#0#19  stp#r1#0              0     18:30:00
# 527  t#r1#saturday#09:00:00#0#19  stp#r1#1              1     19:00:59
#
#     departure_time
# 488       09:00:00
# 489       09:30:59
# 490       09:30:00
# 491       10:00:59
# 492       10:00:00
# 493       10:30:59
# 494       10:30:00
# 495       11:00:59
# 496       11:00:00
# 497       11:30:59
# 498       11:30:00
# 499       12:00:59
# 500       12:00:00
# 501       12:30:59
# 502       12:30:00
# 503       13:00:59
# 504       13:00:00
# 505       13:30:59
# 506       13:30:00
# 507       14:00:59
# 508       14:00:00
# 509       14:30:59
# 510       14:30:00
# 511       15:00:59
# 512       15:00:00
# 513       15:30:59
# 514       15:30:00
# 515       16:00:59
# 516       16:00:00
# 517       16:30:59
# 518       16:30:00
# 519       17:00:59
# 520       17:00:00
# 521       17:30:59
# 522       17:30:00
# 523       18:00:59
# 524       18:00:00
# 525       18:30:59
# 526       18:30:00
# 527       19:00:59

# %%
feed.create_all()
feed.export(as_zip=False)
# Out:
# r0 weekday_peak_1 2.0 12 1 24
# r1 weekday_peak_1 2.0 6 1 12
# r0 weekday_peak_2 2.0 12 1 24
# r1 weekday_peak_2 2.0 4 1 8
# r0 weekday_offpeak 6.0 4 0 24
# r1 weekday_offpeak 6.0 2 1 12
# r0 saturday 10.0 6 0 60
# r1 saturday 10.0 2 0 20
# expect num trips = 264.0
