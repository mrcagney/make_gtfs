# %%
import sys

home = '/home/araichev/make_gtfs/'

sys.path.append(home)
from make_gtfs.make_gtfs import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = '/home/araichev/auckland_network_analysis/data/2016_network/'
feed = Feed(path)

# %%
# Create agency
feed.create_agency()
feed.agency
# Out:
#           agency_name   agency_timezone           agency_url
# 0  Auckland Transport  Pacific/Auckland  https://at.govt.nz/

# %%
feed.create_calendar()
feed.calendar
# Out:
#    service_id  monday  tuesday  wednesday  thursday  friday  saturday  sunday  \
# 0   c_weekday       1        1          1         1       1         0       0
# 1  c_saturday       0        0          0         0       0         1       0
# 2    c_sunday       0        0          0         0       0         0       1
#
#   start_date  end_date
# 0   20160101  20170101
# 1   20160101  20170101
# 2   20160101  20170101

# %%
feed.create_routes()
feed.routes
# Out:
#     route_short_name                                         route_desc  \
# 0                010  City Link, Wynyard Quarter to Karangahape Rd v...
# 1                020  Inner Link. Britomart, Three Lamps, Ponsonby, ...
# 2                030  Grey Lynn to Auckland University via Richmond ...
# 3                031  St Lukes to Auckland University via Richmond R...
# 4                032  Westmere to Auckland University via Williamson...
# 5                033  Benson Rd to Karangahape Rd via Remuera, Hobso...
# 6                040                New Lynn to City via Great North Rd
# 7                060  Avondale Peninsula to Wynyard Quarter via Rose...
# 8                070  New Lynn to Wynyard Quarter via Sandringham Rd...
# 9                071  Avondale, New Windsor to Wynyard Quarter via S...
# 10               072                  Avondale, New Windsor to St Lukes
# 11               080  New Lynn to Wynyard Quarter via White Swan Rd ...
# ...

# %%
feed.create_shapes()
feed.shapes
# Out:
#       shape_id  shape_pt_sequence  shape_pt_lon  shape_pt_lat
# 0         s#r0                  0    174.766857    -36.844297
# 1         s#r0                  1    174.766881    -36.844242
# 2         s#r0                  2    174.767083    -36.843692
# 3         s#r0                  3    174.767222    -36.843297
# 4         s#r0                  4    174.767412    -36.843322
# 5         s#r0                  5    174.767444    -36.843326
# 6         s#r0                  6    174.767628    -36.843373
# 7         s#r0                  7    174.768551    -36.843605
# 8         s#r0                  8    174.768588    -36.843614
# 9         s#r0                  9    174.768551    -36.843703
# 10        s#r0                 10    174.768404    -36.844055
# 11        s#r0                 11    174.768334    -36.844215
# 12        s#r0                 12    174.768273    -36.844347
# 13        s#r0                 13    174.768205    -36.844513
# ...

# %%
feed.get_service_windows()
# Out:
# {'sunday_day': [['07:00:00', '19:00:00']],
#  'weekday_offpeak': [['09:00:00', '16:00:00'], ['18:00:00', '19:00:00']],
#  'weekday_peak': [['07:00:00', '09:00:00'], ['16:00:00', '18:00:00']],
#  'weekday_eve': [['06:00:00', '07:00:00'], ['19:00:00', '24:00:00']],
#  'saturday_eve': [['19:00:00', '24:00:00']],
#  'sunday_eve': [['19:00:00', '24:00:00']],
#  'saturday_day': [['07:00:00', '19:00:00']]}

# %%
feed.create_stops()
feed.stops
# Out:
#        stop_id         stop_name    stop_lon   stop_lat
# 0     st#r51#0  Route 261 stop 0  174.628273 -36.849364
# 1     st#r51#1  Route 261 stop 1  174.612030 -36.816560
# 2    st#r145#0  Route 631 stop 0  174.800167 -36.968794
# 3    st#r145#1  Route 631 stop 1  174.936179 -36.969226
# 4     st#r24#0  Route 144 stop 0  174.854887 -36.877653
# 5     st#r24#1  Route 144 stop 1  174.857139 -36.901265
# 6    st#r137#0  Route 614 stop 0  174.799964 -36.968772
# 7    st#r137#1  Route 614 stop 1  174.764617 -36.850937
# 8     st#r45#0  Route 253 stop 0  174.649462 -36.960195
# 9     st#r45#1  Route 253 stop 1  174.655896 -36.938001
# 10   st#r116#0  Route 462 stop 0  174.712815 -36.722153
# 11   st#r116#1  Route 462 stop 1  174.667520 -36.623750
# 12    st#r13#0  Route 082 stop 0  174.740193 -36.909644
# 13    st#r13#1  Route 082 stop 1  174.754467 -36.844373
# 14    st#r27#0  Route 162 stop 0  174.854414 -36.877817
# 15    st#r27#1  Route 162 stop 1  174.766950 -36.844053
# ...

# %%
feed.create_trips()
feed.trips
# Out:
#       route_id                            trip_id  direction_id shape_id  \
# 0           r0       t#r0#sunday_day#07:00:00#0#0             0     s#r0
# 1           r0       t#r0#sunday_day#07:00:00#0#1             0     s#r0
# 2           r0       t#r0#sunday_day#07:00:00#0#2             0     s#r0
# 3           r0       t#r0#sunday_day#07:00:00#0#3             0     s#r0
# 4           r0       t#r0#sunday_day#07:00:00#0#4             0     s#r0
# 5           r0       t#r0#sunday_day#07:00:00#0#5             0     s#r0
# 6           r0       t#r0#sunday_day#07:00:00#0#6             0     s#r0
# 7           r0       t#r0#sunday_day#07:00:00#0#7             0     s#r0
# 8           r0       t#r0#sunday_day#07:00:00#0#8             0     s#r0
# 9           r0       t#r0#sunday_day#07:00:00#0#9             0     s#r0
# 10          r0      t#r0#sunday_day#07:00:00#0#10             0     s#r0
# 11          r0      t#r0#sunday_day#07:00:00#0#11             0     s#r0
# ...

# %%
feed.create_stop_times()
feed.stop_times
# Out:
#                                 trip_id   stop_id  stop_sequence arrival_time  \
# 0          t#r0#sunday_day#07:00:00#0#0   st#r0#0              0     07:00:00
# 1          t#r0#sunday_day#07:00:00#0#0   st#r0#1              1     07:12:22
# 2          t#r0#sunday_day#07:00:00#0#1   st#r0#0              0     07:07:30
# 3          t#r0#sunday_day#07:00:00#0#1   st#r0#1              1     07:19:52
# 4          t#r0#sunday_day#07:00:00#0#2   st#r0#0              0     07:15:00
# 5          t#r0#sunday_day#07:00:00#0#2   st#r0#1              1     07:27:22
# 6          t#r0#sunday_day#07:00:00#0#3   st#r0#0              0     07:22:30
# 7          t#r0#sunday_day#07:00:00#0#3   st#r0#1              1     07:34:52
# 8          t#r0#sunday_day#07:00:00#0#4   st#r0#0              0     07:30:00
# 9          t#r0#sunday_day#07:00:00#0#4   st#r0#1              1     07:42:22
# 10         t#r0#sunday_day#07:00:00#0#5   st#r0#0              0     07:37:30
# ...

# %%
feed.create_all()
feed.export(path, as_zip=True)
